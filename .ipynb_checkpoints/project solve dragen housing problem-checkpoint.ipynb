# %%
import pandas as pd

# %%
housing=pd.read_csv('housing.csv')
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458    NaN  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458    NaN  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       501 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing['CHAS']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 501    0
# 502    0
# 503    0
# 504    0
# 505    0
# Name: CHAS, Length: 506, dtype: int64

# %%
housing['CHAS'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.287780
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.703336
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.888000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.209000
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
 # %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
housing.hist(bins=50,figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'CRIM'}>,
#         <AxesSubplot:title={'center':'ZN'}>,
#         <AxesSubplot:title={'center':'INDUS'}>,
#         <AxesSubplot:title={'center':'CHAS'}>],
#        [<AxesSubplot:title={'center':'NOX'}>,
#         <AxesSubplot:title={'center':'RM'}>,
#         <AxesSubplot:title={'center':'AGE'}>,
#         <AxesSubplot:title={'center':'DIS'}>],
#        [<AxesSubplot:title={'center':'RAD'}>,
#         <AxesSubplot:title={'center':'TAX'}>,
#         <AxesSubplot:title={'center':'PTRATIO'}>,
#         <AxesSubplot:title={'center':'B'}>],
#        [<AxesSubplot:title={'center':'LSTAT'}>,
#         <AxesSubplot:title={'center':'MEDV'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
import numpy as np
def split_train_test(data, test_ratio):
 np.random.seed(42)
 shuffled = np.random.permutation(len(data))
 print(shuffled)
 test_set_size = int(len(data) * test_ratio)
 test_indices = shuffled[:test_set_size] 
 train_indices = shuffled[test_set_size:]
 return data.iloc[train_indices],data.iloc[test_indices]

# %%
train_set,test_set=split_train_test(housing,0.2)
# Out:
# [173 274 491  72 452  76 316 140 471 500 218   9 414  78 323 473 124 388
#  195 448 271 278  30 501 421 474  79 454 210 497 172 320 375 362 467 153
#    2 336 208  73 496 307 204  68  90 390  33  70 470   0  11 281  22 101
#  268 485 442 290  84 245  63  55 229  18 351 209 395  82  39 456  46 481
#  444 355  77 398 104 203 381 489  69 408 255 392 312 234 460 324  93 137
#  176 417 131 346 365 132 371 412 436 411  86  75 477  15 332 423  19 325
#  335  56 437 409 334 181 227 434 180  25 493 238 244 250 418 117  42 322
#  347 182 155 280 126 329  31 113 148 432 338  57 194  24  17 298  66 211
#  404  94 154 441  23 225 433 447   5 116  45  16 468 360   3 405 185  60
#  110 321 265  29 262 478  26   7 492 108  37 157 472 118 114 175 192 272
#  144 373 383 356 277 220 450 141 369  67 361 168 499 394 400 193 249 109
#  420 145  92 152 222 304  83 248 165 163 199 231  74 311 455 253 119 284
#  302 483 357 403 228 261 237 386 476  36 196 139 368 247 287 378  59 111
# ...

# %%
print(f"Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: 405
# Rows in test set: 101

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing,test_size=0.2,random_state=42)
print(f"Rows in train set :{len(train_set)}\nRows in test set:{len(test_set)}\n")
# Out:
# Rows in train set :404
# Rows in test set:102

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split=StratifiedShuffleSplit(n_splits=1, test_size=0.2 , random_state=42)
for train_index , test_index in split.split(housing, housing['CHAS']):
 strat_train_set=housing.loc[train_index]
 strat_test_set=housing.loc[test_index]

# %%
strat_train_set
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276
#
#      PTRATIO       B  LSTAT  MEDV
# 254     16.4  392.89   6.57  21.9
# 348     17.0  390.94   5.99  24.5
# ...

# %%
strat_train_set.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  400.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.282963
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.713328
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086963    0.000000    5.190000    0.000000    0.453000    5.883000
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.213500
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630250
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
strat_train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404 entries, 254 to 216
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     404 non-null    float64
#  1   ZN       404 non-null    float64
#  2   INDUS    404 non-null    float64
#  3   CHAS     404 non-null    int64
#  4   NOX      404 non-null    float64
#  5   RM       400 non-null    float64
#  6   AGE      404 non-null    float64
#  7   DIS      404 non-null    float64
#  8   RAD      404 non-null    int64
#  9   TAX      404 non-null    int64
#  10  PTRATIO  404 non-null    float64
#  11  B        404 non-null    float64
#  12  LSTAT    404 non-null    float64
#  13  MEDV     404 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 47.3 KB

# %%
strat_train_set['CHAS'].value_counts()
# Out:
# 0    376
# 1     28
# Name: CHAS, dtype: int64

# %%
strat_test_set['CHAS'].value_counts()
# Out:
# 0    95
# 1     7
# Name: CHAS, dtype: int64

# %%
376/28
# Out:
# 13.428571428571429

# %%
95/7
# Out:
# 13.571428571428571

# %% [markdown]
# # Looking For Correlations

# %%
strat_train_set
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276
#
#      PTRATIO       B  LSTAT  MEDV
# 254     16.4  392.89   6.57  21.9
# 348     17.0  390.94   5.99  24.5
# ...

# %%
housing=strat_train_set.copy()
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276
#
#      PTRATIO       B  LSTAT  MEDV
# 254     16.4  392.89   6.57  21.9
# 348     17.0  390.94   5.99  24.5
# ...

# %%
housing.shape
# Out:
# (404, 14)

# %%
corr_matrix = housing.corr()
corr_matrix['MEDV'].sort_values(ascending=False)
# it is a strong positive correlation means if you increase one value the also increase other ( it liks b/t 1 to -1 )
# This is strongly positive related with RM & Zn & B  
# This is strongly negative related with LSTAT , TAX , RAD ect
# Out:
# MEDV       1.000000
# RM         0.678637
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
#corr_matrix['ZN'].sort_values(ascending=False)

# %%
#corr_matrix['RM'].sort_values(ascending=False)

# %%
from pandas.plotting import scatter_matrix
attribute=["MEDV","ZN","RM","LSTAT"]
scatter_matrix(housing[attribute], figsize=(12,8))
# Out:
# array([[<AxesSubplot:xlabel='MEDV', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='ZN', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='RM', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='ZN'>,
#         <AxesSubplot:xlabel='ZN', ylabel='ZN'>,
#         <AxesSubplot:xlabel='RM', ylabel='ZN'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='ZN'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='RM'>,
#         <AxesSubplot:xlabel='ZN', ylabel='RM'>,
#         <AxesSubplot:xlabel='RM', ylabel='RM'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='RM'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='ZN', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='RM', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
# here two interesting graph 1) MEDV & RM 2) MEDV & LSTAT  
# we see in detail these graph

# %%
housing.plot(kind="scatter", x="RM", y="MEDV", alpha=0.8)
# alpha if dencity is large then show dark can pass 0.1 ,0.3 or ect
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %% [markdown]
# ## Trying out Attribute Combinations

# %%
# Now if given data attribute is not enouhh for u the u can create a new attribute with help of given attribute
# i here i am going to create new attribute wityh combination of RM & TAX attr is TAXRM

# %%
housing['TAXRM']= housing['TAX']/housing['RM']
# i need to put it in top

# %%
housing['TAXRM']
# Out:
# 254     51.571709
# 348     42.200452
# 476    102.714374
# 321     45.012547
# 326     45.468948
#           ...
# 155     65.507152
# 423    109.126659
# 98      35.294118
# 455    102.068966
# 216     46.875000
# Name: TAXRM, Length: 404, dtype: float64

# %%
corr_matrix = housing.corr()
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.678637
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# TAXRM     -0.526560
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
housing.plot(kind="scatter", x="TAXRM", y="MEDV")
# Out:
# <AxesSubplot:xlabel='TAXRM', ylabel='MEDV'>

# %%
housing=strat_train_set.drop("MEDV", axis=1)
housing_lables = strat_train_set["MEDV"].copy()

# %% [markdown]
# # Handel Missing Values

# %%
# 1) Fillna Means you can fill the missing values by Median or other values 
# 2) Dropna Means you can drop/remove the missing value
# 3) You can remove the particular attribute by using drop with axis=0/1
#    when i put inset TRUE then it apply on original data

# %%
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276
#
#      PTRATIO       B  LSTAT
# 254     16.4  392.89   6.57
# 348     17.0  390.94   5.99
# 476     20.2  396.21  18.68
# ...

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  400.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.282963
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.713328
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086963    0.000000    5.190000    0.000000    0.453000    5.883000
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.213500
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630250
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
housing.shape
# Out:
# (404, 13)

# %%
a=housing.dropna(subset=["RM"])
a.shape
# but not apply changes on original housing data
# Out:
# (400, 13)

# %%
a=housing.drop("RM", axis=1)
a
# but not apply on original data set
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX   AGE     DIS  RAD  TAX  PTRATIO  \
# 254  0.04819  80.0   3.64     0  0.392  32.0  9.2203    1  315     16.4
# 348  0.01501  80.0   2.01     0  0.435  29.7  8.3440    4  280     17.0
# 476  4.87141   0.0  18.10     0  0.614  93.6  2.3053   24  666     20.2
# 321  0.18159   0.0   7.38     0  0.493  54.3  4.5404    5  287     19.6
# 326  0.30347   0.0   7.38     0  0.493  28.9  5.4159    5  287     19.6
# ..       ...   ...    ...   ...    ...   ...     ...  ...  ...      ...
# 155  3.53501   0.0  19.58     1  0.871  82.6  1.7455    5  403     14.7
# 423  7.05042   0.0  18.10     0  0.614  85.1  2.0218   24  666     20.2
# 98   0.08187   0.0   2.89     0  0.445  36.9  3.4952    2  276     18.0
# 455  4.75237   0.0  18.10     0  0.713  86.5  2.4358   24  666     20.2
# 216  0.04560   0.0  13.89     1  0.550  56.0  3.1121    5  276     16.4
#
#           B  LSTAT
# 254  392.89   6.57
# 348  390.94   5.99
# 476  396.21  18.68
# 321  396.90   6.87
# ...

# %%
a.shape
# Out:
# (404, 12)

# %%
# Now going to fill with median value 
median = housing["RM"].median()
median
# Out:
# 6.2135

# %%
housing["RM"].fillna(median)
# now fill all RM missing values with median value
# but original data fram unchange
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.376
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: RM, Length: 404, dtype: float64

# %%
# Now which median value you find need to use all time if model is need to again testing so need to take save

# %%
# This median value you can generate automatic by useing sklearn.impute

# %%
from sklearn.impute import SimpleImputer
imputer= SimpleImputer(strategy="median")
imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
# now check which value it fit on place of null value

# %%
imputer.statistics_
# Out:
# array([2.86735e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.38000e-01,
#        6.21350e+00, 7.82000e+01, 3.12220e+00, 5.00000e+00, 3.37000e+02,
#        1.90000e+01, 3.90955e+02, 1.15700e+01])

# %%
# now you can see it generate median value for each 14th column

# %%
X = imputer.transform(housing)
X
# Out:
# array([[4.81900e-02, 8.00000e+01, 3.64000e+00, ..., 1.64000e+01,
#         3.92890e+02, 6.57000e+00],
#        [1.50100e-02, 8.00000e+01, 2.01000e+00, ..., 1.70000e+01,
#         3.90940e+02, 5.99000e+00],
#        [4.87141e+00, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         3.96210e+02, 1.86800e+01],
#        ...,
#        [8.18700e-02, 0.00000e+00, 2.89000e+00, ..., 1.80000e+01,
#         3.93530e+02, 3.57000e+00],
#        [4.75237e+00, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         5.09200e+01, 1.81300e+01],
#        [4.56000e-02, 0.00000e+00, 1.38900e+01, ..., 1.64000e+01,
#         3.92800e+02, 1.35100e+01]])

# %%
housing_tr=pd.DataFrame(X, columns=housing.columns)
housing_tr
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 0    0.04819  80.0   3.64   0.0  0.392  6.108  32.0  9.2203   1.0  315.0
# 1    0.01501  80.0   2.01   0.0  0.435  6.635  29.7  8.3440   4.0  280.0
# 2    4.87141   0.0  18.10   0.0  0.614  6.484  93.6  2.3053  24.0  666.0
# 3    0.18159   0.0   7.38   0.0  0.493  6.376  54.3  4.5404   5.0  287.0
# 4    0.30347   0.0   7.38   0.0  0.493  6.312  28.9  5.4159   5.0  287.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...   ...    ...
# 399  3.53501   0.0  19.58   1.0  0.871  6.152  82.6  1.7455   5.0  403.0
# 400  7.05042   0.0  18.10   0.0  0.614  6.103  85.1  2.0218  24.0  666.0
# 401  0.08187   0.0   2.89   0.0  0.445  7.820  36.9  3.4952   2.0  276.0
# 402  4.75237   0.0  18.10   0.0  0.713  6.525  86.5  2.4358  24.0  666.0
# 403  0.04560   0.0  13.89   1.0  0.550  5.888  56.0  3.1121   5.0  276.0
#
#      PTRATIO       B  LSTAT
# 0       16.4  392.89   6.57
# 1       17.0  390.94   5.99
# ...

# %%
housing_tr.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.282275
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.709812
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086963    0.000000    5.190000    0.000000    0.453000    5.884750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.213500
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %% [markdown]
# ## Scikit Learn Design

# %%
# Primarily, three type of objects
# 1. Estimators - It estimates some parameter based on a dataset. Eg. imputer
# It has a fit method and transform method. Fit method - Fits the dataset and calculate internal parameters

# 2) Transformers - transform method takes input and return output based on the learnings from fit().
#    It also has a convenience function called fit_transform() which fits and then transforms.
# 3) Predictors - LinearRegression model is an example of predictor. fit() and predict are two common functions. 
#    It also give score() function which will evaluate the predictions.

# %% [markdown]
# ## Feature Scaling

# %%
# Primarily two type of feature scalind methods:
# 1) Min-max scalling (Normalization)
#    (value - min)/(max - min)
#   For this Sklearn provide a class call MinMaxScaller
 
# 2) Standardization 
#   (value - mean)/std
#   Sklearn provide a calass called StandardScaller For this

# %% [markdown]
# ## Creating Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipline = Pipeline([
   ('imputer', SimpleImputer(strategy="median")),
   ('std_scaler', StandardScaler()),                      
])

# %%
#housing_num_tr=my_pipline.fit_transform(housing_tr)
housing_num_tr=my_pipline.fit_transform(housing)
housing_num_tr
# it return numpy array this num py array use in prediction
# here in fit_transform() you can use both housing or housing_tr because you already pass imputer in you pipline
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, ..., -0.97491834,
#          0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, ..., -0.69277865,
#          0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.44624347,  0.81480158],
#        ...,
#        [-0.43525657, -0.4898311 , -1.23083158, ..., -0.22254583,
#          0.41831233, -1.27603303],
#        [ 0.14210728, -0.4898311 ,  0.98336806, ...,  0.81196637,
#         -3.15239177,  0.73869575],
#        [-0.43974024, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.41070422,  0.09940681]])

# %%
housing_num_tr.shape
# Out:
# (404, 13)

# %% [markdown]
# ## Select a desigre model for Dragon Real EState

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
#model = LinearRegression()
#model = DecisionTreeRegressor()
model = RandomForestRegressor()
model.fit(housing_num_tr, housing_lables)
# Out:
# RandomForestRegressor()

# %%
some_data = housing.iloc[:5]
some_labels = housing_lables.iloc[:5]
prepared_data = my_pipline.transform(some_data)
model.predict(prepared_data)
# Out:
# array([22.629, 25.525, 16.34 , 23.296, 23.401])

# %%
some_labels
# Out:
# 254    21.9
# 348    24.5
# 476    16.7
# 321    23.1
# 326    23.0
# Name: MEDV, dtype: float64

# %%
list(some_labels)
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %% [markdown]
# ## Evaluating The Model

# %%
from sklearn.metrics import mean_squared_error
housing_prediction = model.predict(housing_num_tr)
mse = mean_squared_error(housing_lables, housing_prediction)
rmse = np.sqrt(mse)
rmse
# Now here show 0 Error means it is overfitting  You Learn on google OverFitting & UnderFitting
# Out:
# 1.1576139712510563

# %% [markdown]
# ## Useing better evaluation techniques - Cross validatioin

# %%
# It is use for make multiple groups of the train dataset and apply prediction each one the evaluate the error all these 
from sklearn.model_selection import cross_val_score
score = cross_val_score(model, housing_num_tr, housing_lables, scoring="neg_mean_squared_error", cv=10)
rmsc_score = np.sqrt(-score)
rmsc_score
# Out:
# array([2.78026341, 2.73401728, 4.35127808, 2.59140877, 3.22778947,
#        2.76518524, 4.64997107, 3.23344145, 3.23585664, 3.15313123])

# %%
# result of DecisionTreeRegression
# array([4.20035195, 4.26701953, 5.21712631, 3.82952461, 5.3431535 ,
#       4.31985937, 7.45194204, 5.47967199, 4.15223144, 6.00594712])

# %%
def print_scores(scores):
    print("Scores", scores)
    print("Mean", scores.mean())
    print("Standared devistion", scores.std)

# %%
print_scores(rmsc_score)
# Out:
# Scores [2.78026341 2.73401728 4.35127808 2.59140877 3.22778947 2.76518524
#  4.64997107 3.23344145 3.23585664 3.15313123]
# Mean 3.2722342634120793
# Standared devistion <built-in method std of numpy.ndarray object at 0x000000000827F710>

# %% [markdown]
# ## Convert this file in to py file and run with python using joblib

# %% [markdown]
# ## Save the model

# %%
from joblib import dump, load
dump(model,"Dragon.joblib")
# Out:
# ['Dragon.joblib']

# %% [markdown]
# ## Testing the model on test Data

# %%
X_test = strat_test_set.drop("MEDV", axis=1)
Y_test = strat_test_set["MEDV"].copy()
X_test_prepared = my_pipline.transform(X_test)
fina_predications = model.predict(X_test_prepared)
final_mse = mean_squared_error(Y_test, fina_predications)
final_rmse = np.sqrt(final_mse)
print(fina_predications, list(Y_test))
final_rmse
# Out:
# [24.515 11.622 25.53  22.098 18.829 14.973 20.088 14.544 31.863 40.038
#  20.008 11.904 24.225 27.875 19.6   10.62  31.661 14.523 23.45  18.759
#  20.132 18.226 16.186 22.147 17.867 30.902 16.223 32.543  8.884 33.873
#  23.574 21.451 23.083 10.976 20.788 11.285 42.003 24.552 23.438 41.821
#  23.878 29.402 20.571 20.817 19.527 33.531 44.243 20.007 20.393 21.871
#  21.764 14.734 21.44  15.231 24.632 32.812 42.504 28.195 19.603 22.175
#  46.915 10.089 18.923 25.463 15.085 32.733 19.471 18.046 19.046 33.998
#  27.326 22.837 21.747 22.371 35.475 12.788 15.946 20.143 20.787 21.348
#  22.385 21.584 14.399 22.728 20.756 21.08  13.94  21.327 22.122 23.177
#  18.633 26.906  7.254 25.776 18.736 30.065 20.089 31.185 14.443 26.209
# ...

# %%
prepared_data[0]
# Out:
# array([-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
#        -0.24582675, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
#        -0.97491834,  0.41164221, -0.86091034])

# %% [markdown]
# ## Using the Model

# %%
from joblib import dump, load
import numpy as np
model = load("Dragon.joblib")

# %%
features= np.array([[-0.93942006,  5.12628155, -1.12165014, -0.27288841, -1.42262747,
       -0.24582675, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
       -0.97491834,  0.41164221, -0.86091034]])
model.predict(features)
# Means the user pass this type of feature value the it return the price of housing
# Out:
# array([22.755])
